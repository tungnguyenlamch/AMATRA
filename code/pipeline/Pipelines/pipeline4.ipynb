# %%
import os
import sys
import matplotlib.pyplot as plt
import cv2

# 1. Setup Paths
NOTEBOOK_DIR = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(NOTEBOOK_DIR, '..', '..', '..'))
sys.path.insert(0, os.path.join(BASE_DIR, 'code'))

# 2. Import the new Pipeline Class
from pipeline.Utils.MangaPipeline import MangaPipeline

# %%
# 3. Initialize Pipeline (Loads models once)
YOLO_PATH = os.path.join(BASE_DIR, "models","bubble-detection","YOLO_Ultralytics","yolov8s.pt")
pipeline = MangaPipeline(YOLO_PATH)
# Out:
# 2025-12-23 14:41:13.450 | INFO     | manga_ocr.ocr:__init__:16 - Loading OCR model from kha-white/manga-ocr-base
# Initializing Pipeline...
# 2025-12-23 14:41:17.079 | INFO     | manga_ocr.ocr:__init__:28 - Using CPU
# 2025-12-23 14:41:17.860 | INFO     | manga_ocr.ocr:__init__:35 - OCR ready
# MangaOCR model loaded
# Device set to use cpu
# Pipeline Ready.

# %%
# 4. Define Image Path
IMG_PATH = os.path.join(BASE_DIR, "data/Manga109_released_2023_12_07/images/Count3DeKimeteAgeru/005.jpg")

# 5. Run the Pipeline
final_image, bubble_data = pipeline.process(IMG_PATH)
# Out:
# Found 15 bubbles.

# %%
# 6. Display Result
plt.figure(figsize=(15, 20))
plt.imshow(final_image)
plt.axis('off')
plt.show()

# %%
# 7. Inspect Text Data (Optional)
for i, b in enumerate(bubble_data):
    print(f"Bubble {i}:")
    print(f"  OCR: {b['ocr_text']}")
    print(f"  Trans: {b['translated_text']}\n")
# Out:
# Bubble 0:
#   OCR: それよりキミさ体育会でチアガールやんない？
#   Trans: More than that, I'm a cheerleader at the athletic meeting?
#
# Bubble 1:
#   OCR: 理事長の命令とはいえ
#   Trans: It is an order of the chief of the board.
#
# Bubble 2:
#   OCR: 創立以来の名門男子校が共学！！
#   Trans: Since its founding, the prestigious boys' school has been co-educated!
#
# Bubble 3:
#   OCR: えーとそっちの大きい人はー
#   Trans: The big man in the same way.
#
# Bubble 4:
#   OCR: バスケ．．．
#   Trans: Buske...
#
# Bubble 5:
#   OCR: 女子なんぞ勉学のさまたげになるだけだ！！
#   Trans: I'm just looking forward to studying girls!!
#
# Bubble 6:
#   OCR: 生徒会長桜井亮
#   Trans: Student Chairman Ryo SAKURAI
#
# Bubble 7:
#   OCR: 私たち
#   Trans: We
#
# Bubble 8:
#   OCR: やりたいことはもう決まってるんだ
#   Trans: I've already decided what I want to do.
#
# Bubble 9:
#   OCR: おとなしいお嬢さんばかりで何の心配も．．．
#   Trans: I'm just worried about it....
#
# Bubble 10:
#   OCR: 大丈夫ですよ学院長
#   Trans: The director of the academy is OK.
#
# Bubble 11:
#   OCR: やりたいこと？
#   Trans: What do you want to do?
#
# Bubble 12:
#   OCR: ねっ
#   Trans: Net
#
# Bubble 13:
#   OCR: なんだあの男っ！！
#   Trans: What a man!!
#
# Bubble 14:
#   OCR: まったく嘆かわしい！！
#   Trans: I'm completely lamented!
